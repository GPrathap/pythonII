# %% [markdown]
# <a href="https://colab.research.google.com/github/GPrathap/pythonII/blob/master/sec_pandas/pandas_introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # What can we do with **Pandas**?
# Pandas සමඟ අපට කුමක් කළ හැකිද?
#
# Pandas நாம் என்ன செய்ய முடியும்?

# %% [markdown]
# ![Selection_226.png](data:image/png;base64,...)

# %% [markdown]
# # Where can we use **Pandas** based on what you have learnt so far?
#
# ඔබ මෙතෙක් ඉගෙන ගත් කරුණු මත පදනම්ව Pandas අපට යොදා ගන්නේ කෙසේද ?
#
# நீங்கள் இதுவரை கற்றுக்கொண்டவற்றின் அடிப்படையில் Pandas நாங்கள் எங்கு பொருத்த முடியும்?

# %% [markdown]
# ![Selection_227.png](data:image/png;base64,...)

# %% [markdown]
# # Let us look at some examples.
#
# අපි උදාහරණ කිහිපයක් දෙස බලමු.
#
# சில உதாரணங்களைப் பார்ப்போம்.

# %%
import pandas as pd

dataset_dir = "https://raw.githubusercontent.com/GPrathap/pythonII/master/dataset/"
olympic_datset_repo = dataset_dir + "olympic_games/olympic_hosts.csv"
cryptocurrencies_dataset_repo = dataset_dir + "cryptocurrencies/Aave.csv"

cryptocurrencies_dataset = pd.read_csv(cryptocurrencies_dataset_repo)
cryptocurrencies_dataset.to_csv('/content/sample_data/cryptocurrencies.csv')

cryptocurrencies_dataset
# Out:
#        SNo        Date   Price    Open    High     Low       Vol.  Change %
# 0        1  2018-01-30    0.15    0.17    0.17    0.14   530470.0     -7.95
# 1        2  2018-01-31    0.14    0.15    0.15    0.13   396050.0    -11.10
# 2        3  2018-02-01    0.11    0.14    0.14    0.11   987260.0    -17.46
# 3        4  2018-02-02    0.10    0.11    0.11    0.08  1810000.0     -8.32
# 4        5  2018-02-03    0.11    0.10    0.12    0.09  1200000.0      6.85
# ...    ...         ...     ...     ...     ...     ...        ...       ...
# 1270  1271  2021-08-20  409.19  405.27  420.72  403.54   155020.0      0.99
# 1271  1272  2021-08-21  399.84  409.19  415.39  393.43   145060.0     -2.28
# 1272  1273  2021-08-22  400.96  399.84  408.44  386.63    88070.0      0.28
# 1273  1274  2021-08-23  408.31  400.96  415.14  399.45   139750.0      1.84
# 1274  1275  2021-08-24  401.02  408.33  413.91  398.49   116250.0     -1.79
#
# [1275 rows x 8 columns]

# %% [markdown]
# How can we find the maximum price?
#
# What is the ''SNo'' that has the highest ''Vol.''?
#
# What is the mean value of price?

# %% [markdown]
# අපි උපරිම මිල සොයා ගන්නේ කෙසේද?
#
# වැඩිම "Vol." ඇති "SNo" කුමක්ද?
#
# මිලෙහි මධ්‍යන්‍ය වටිනාකම කුමක්ද?

# %% [markdown]
# அதிகபட்ச விலையை நாம் எப்படி கண்டுபிடிக்க முடியும்?
#
# அதிக அளவு கொண்ட "SNo" என்றால் "Vol."?
#
# விலையின் சராசரி மதிப்பு என்ன?
